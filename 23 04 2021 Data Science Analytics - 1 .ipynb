# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Task 1: Data pre-processing and data exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt             
# %matplotlib inline     
sns.set(color_codes=True)

# %% [markdown]
# a. Use Pandas to load the data and report the number of data points (rows) in the training set and the test set, respectively.

# %%
df_train = pd.read_csv("trndata.csv")

df_train.head(1000)
# Out:
#          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 0    0.3315  0.2156  0.6802  0.1434  0.6825  0.2720  0.6223  0.2092  0.7961
# 1    0.0939  1.0089  0.0365  0.6944  0.0908  0.4961  0.0722  0.6521 -0.0130
# 2    0.5184  0.2283  0.5300  0.6884  0.7456  0.6171  0.6136  0.5928  0.7678
# 3    0.4208  0.6740  0.1651  0.7592  0.1810  0.5448  0.1707  0.7554  0.1635
# 4    0.3130  0.6465  0.5908  0.6924  0.7664  0.6262  1.7177  0.0150  0.0851
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 995  0.1312  0.7093  0.3948  0.7673  0.5272  0.7554  1.7433 -0.0125  0.0235
# 996  0.1263  0.6105  0.2655  0.8748  0.2336  1.0768  0.1833  0.9726  0.3004
# 997  0.6043  0.4914  1.0900  0.5961  1.0569  0.8966  1.0279  0.6694  1.2127
# 998  1.0284  0.0893  0.4097  0.9375  0.2813  0.6865  0.3827  0.9620  0.2830
# 999 -0.0197  0.7719  0.4634  0.5700  0.5143  0.6520 -0.0258  1.7626 -0.0173
#
#         F10     F11     F12  L
# ...

# %%
df_test = pd.read_csv("tstdata.csv")

df_test.head(300)
# Out:
#          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 0    0.5803  0.4980  0.8809  0.8215  1.0133  0.9187  0.8508  0.8496  0.9996
# 1    0.0026  0.6084  0.2808  0.6282  0.2995  0.7513 -0.0107  1.7503 -0.0622
# 2   -0.0115  1.1193  0.2201  1.3189  0.2656  1.4039 -0.0067  1.7438  0.0013
# 3   -0.0536  1.0370  0.0558  1.2483  0.2640  1.1456  0.0140  1.7156  0.0125
# 4    0.5021  0.4270  0.6450  0.8325  0.7560  0.9235  0.7289  0.7352  0.7735
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 295 -0.0101  0.1953  0.2330  0.2586  0.3193  0.2981 -0.0064  1.7405 -0.0153
# 296  0.5149  0.3510  0.8312  0.5286  0.9377  0.6047  0.8596  0.4935  0.9111
# 297  0.5609  0.2518  0.7441  0.5600  0.8237  0.6641  0.8240  0.4697  0.9044
# 298  0.3725  0.7269  0.7023  1.0030  0.8466  1.0881  0.7118  0.9898  0.9563
# 299  0.4213  0.6770  0.1901  1.4787  0.1049  0.9374  0.1943  1.4687  0.1839
#
#         F10     F11     F12  L
# ...

# %% [markdown]
# b. Report the number of features in the dataset and the number of data points in each class for the training set and the test set, separately.

# %%
df_train.shape
# Out:
# (1000, 13)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   F1      1000 non-null   float64
#  1   F2      1000 non-null   float64
#  2   F3      1000 non-null   float64
#  3   F4      1000 non-null   float64
#  4   F5      1000 non-null   float64
#  5   F6      1000 non-null   float64
#  6   F7      1000 non-null   float64
#  7   F8      1000 non-null   float64
#  8   F9      1000 non-null   float64
#  9   F10     1000 non-null   float64
#  10  F11     1000 non-null   float64
#  11  F12     1000 non-null   float64
#  12  L       1000 non-null   int64
# dtypes: float64(12), int64(1)
# memory usage: 101.7 KB

# %%
df_test.shape
# Out:
# (300, 13)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   F1      300 non-null    float64
#  1   F2      300 non-null    float64
#  2   F3      300 non-null    float64
#  3   F4      300 non-null    float64
#  4   F5      300 non-null    float64
#  5   F6      300 non-null    float64
#  6   F7      300 non-null    float64
#  7   F8      300 non-null    float64
#  8   F9      300 non-null    float64
#  9   F10     300 non-null    float64
#  10  F11     300 non-null    float64
#  11  F12     300 non-null    float64
#  12  L       300 non-null    int64
# dtypes: float64(12), int64(1)
# memory usage: 30.6 KB

# %%
data_points_train_classwise=( df_train.groupby('L'))
print(list(data_points_train_classwise))
# Out:
# [(1,          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 0    0.3315  0.2156  0.6802  0.1434  0.6825  0.2720  0.6223  0.2092  0.7961
# 2    0.5184  0.2283  0.5300  0.6884  0.7456  0.6171  0.6136  0.5928  0.7678
# 12   0.0760  0.5010  0.1870  0.7011  0.1728  0.8475  0.2300  0.6536  0.1616
# 15   0.3334  0.5468  0.6072  0.7549  0.6294  0.9322  0.5850  0.7859  0.6324
# 17   0.1703  0.2234  0.2677  0.3477  0.2734  0.4324  0.1222  0.5213  0.2333
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 991  0.3376  0.7419  0.4848  1.2210  0.6335  1.2910  0.5921  1.0881  0.6010
# 992  0.9463  0.0202  1.3809  0.1522  1.6763  0.0578  1.3851  0.1532  1.6485
# 994  0.1724  0.3817  0.1702  0.7203  0.2873  0.7049  0.2921  0.5731  0.3515
# 996  0.1263  0.6105  0.2655  0.8748  0.2336  1.0768  0.1833  0.9726  0.3004
# 997  0.6043  0.4914  1.0900  0.5961  1.0569  0.8966  1.0279  0.6694  1.2127
#
#         F10     F11     F12  L
# ...

# %%
data_points_test_classwise=( df_test.groupby('L'))
print(list(data_points_test_classwise))
# Out:
# [(1,          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 0    0.5803  0.4980  0.8809  0.8215  1.0133  0.9187  0.8508  0.8496  0.9996
# 4    0.5021  0.4270  0.6450  0.8325  0.7560  0.9235  0.7289  0.7352  0.7735
# 6    0.2914  0.5182  0.4759  0.7850  0.5531  0.8765  0.4609  0.8011  0.6070
# 7    0.2185  0.1380  0.4103  0.1364  0.3322  0.3136  0.3045  0.2596  0.3964
# 8    0.4108  0.3170  0.6425  0.5097  0.7467  0.5559  0.7082  0.4243  0.8347
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 288  0.1160  0.6119  0.3001  0.8176  0.3282  0.9500  0.2109  0.9272  0.3985
# 290  0.4003  0.1153  0.5069  0.3174  0.6645  0.2569  0.4884  0.3400  0.6472
# 296  0.5149  0.3510  0.8312  0.5286  0.9377  0.6047  0.8596  0.4935  0.9111
# 297  0.5609  0.2518  0.7441  0.5600  0.8237  0.6641  0.8240  0.4697  0.9044
# 298  0.3725  0.7269  0.7023  1.0030  0.8466  1.0881  0.7118  0.9898  0.9563
#
#         F10     F11     F12  L
# ...

# %% [markdown]
# c. Do random permutations for the training data using the function, shuffle, from sklearn.utils. You must set a value for the parameter, random_state. Save the data as Training_set_I.

# %%
from sklearn.utils import shuffle
Training_set_I = shuffle(df_train.reset_index(drop=True),random_state=42)

# %%
Training_set_I
# Out:
#          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 521 -0.0205  1.0804  0.1990  1.1713  0.2044  1.3011 -0.0630  1.8070 -0.1090
# 737  0.2109  0.6045  0.2995  0.9821  0.5221  0.9051  0.3581  0.9091  0.4162
# 740  0.7918 -0.0676  0.9720  0.0902  1.0691  0.1199  1.7815 -0.0586  1.9628
# 660  0.2356  0.2608  0.3491  0.4312  0.5015  0.3656  0.3259  0.4589  0.3623
# 411  0.4731  0.0856  0.7429  0.1325  0.9045  0.0817  0.8110  0.0462  0.8391
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 106  0.0187  0.6936  0.1526  0.8764  0.2685  0.8772 -0.0240  1.7611  0.0566
# 270  0.5597  0.2298  0.8849  0.3551  1.0343  0.3724  1.0940  0.1069  1.1169
# 860  0.5224  0.0097  0.7253  0.1418  0.8516  0.1318  1.6666  0.0734  0.0191
# 435  1.1679 -0.0767  1.1519  0.5657  0.8234  1.0579  1.0611  0.6778  0.6292
# 102  1.0521  0.0665  0.7528  0.9807  0.6024  0.8703  0.7803  0.9460  0.7222
#
#         F10     F11     F12  L
# ...

# %% [markdown]
# d. Show one scatter plot for the training set, that is, one feature against another feature. It is your choice which two features you want to use in the scatter plot.

# %%
import seaborn as sns
sns.lmplot('F1','F9', Training_set_I, hue='L', fit_reg=False)
fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.show()
# Out:
# C:\ProgramData\Anaconda2021\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.lmplot('F11','F6', df_train, hue='L', fit_reg=False)
fig = plt.gcf()
fig.set_size_inches(15, 10)
plt.show()
# Out:
# C:\ProgramData\Anaconda2021\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Task 2: Perform principal component analysis (PCA) on the training set Using Scikit-Learn

# %%
import numpy as np 
import pandas as pd
df_pca = Training_set_I
df_pca.head()
# Out:
#          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 521 -0.0205  1.0804  0.1990  1.1713  0.2044  1.3011 -0.0630  1.8070 -0.1090
# 737  0.2109  0.6045  0.2995  0.9821  0.5221  0.9051  0.3581  0.9091  0.4162
# 740  0.7918 -0.0676  0.9720  0.0902  1.0691  0.1199  1.7815 -0.0586  1.9628
# 660  0.2356  0.2608  0.3491  0.4312  0.5015  0.3656  0.3259  0.4589  0.3623
# 411  0.4731  0.0856  0.7429  0.1325  0.9045  0.0817  0.8110  0.0462  0.8391
#
#         F10     F11     F12  L
# 521  2.1311  0.0911  1.6254  3
# 737  1.0468  0.3561  0.9154  1
# 740  0.0439  0.0240 -0.0271  3
# 660  0.5480  0.3415  0.4391  1
# 411  0.1784  0.7406  0.1352  1

# %%
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(Training_set_I)
X_scaled[:12]
Y=Training_set_I.L

# %%
features = X_scaled.T
cov_matrix = np.cov(features)
cov_matrix[:12]
# Out:
# array([[ 1.001001  , -0.75471526,  0.56433903, -0.08401941,  0.34343038,
#         -0.28853498,  0.17609845, -0.15893355,  0.45426342, -0.42198179,
#          0.604979  ,  0.16815057, -0.08587793],
#        [-0.75471526,  1.001001  , -0.49172702,  0.44655724, -0.35184748,
#          0.56249526, -0.1370039 ,  0.27262901, -0.40242914,  0.58449067,
#         -0.55395936,  0.20198243,  0.21013702],
#        [ 0.56433903, -0.49172702,  1.001001  , -0.4628483 ,  0.91858192,
#         -0.39273282,  0.67585613, -0.52153176,  0.67589225, -0.20481604,
#          0.55296747, -0.07243361,  0.0065226 ],
#        [-0.08401941,  0.44655724, -0.4628483 ,  1.001001  , -0.4668444 ,
#          0.85307337, -0.36080399,  0.68778213, -0.27579175,  0.39809083,
#         -0.16349938,  0.64636086, -0.00553187],
#        [ 0.34343038, -0.35184748,  0.91858192, -0.4668444 ,  1.001001  ,
#         -0.40353133,  0.73207613, -0.55251784,  0.65227636, -0.10501128,
#          0.39343662, -0.12622834,  0.03888245],
# ...

# %%
values, vectors = np.linalg.eig(cov_matrix)
values[:12]
# Out:
# array([5.28493927, 2.76401583, 1.89455148, 0.99574859, 0.77455389,
#        0.57299501, 0.22374882, 0.18156552, 0.01156239, 0.04173103,
#        0.0266788 , 0.12433976])

# %%
vectors[:12]
# Out:
# array([[-2.67751648e-01,  2.54704897e-01,  1.67703997e-01,
#         -5.70920582e-01, -1.05790343e-01, -1.29011416e-01,
#          1.01736627e-01, -3.14772120e-01,  1.80193348e-01,
#         -4.25881719e-01,  1.06065276e-01, -3.70231029e-01,
#          9.96314140e-02],
#        [ 3.19901055e-01, -1.93167512e-01,  1.49110989e-01,
#          4.27091165e-01,  1.28558256e-01,  1.20686645e-01,
#          5.69191004e-01, -4.29932994e-01,  1.02748101e-01,
#         -2.92103305e-01, -1.55970665e-02, -1.05838410e-01,
#          9.20263886e-02],
#        [-3.75041074e-01, -3.65627063e-02,  3.08792593e-01,
#          6.73292982e-02, -1.69009525e-01,  1.40077253e-01,
#          1.81373555e-01,  9.16735413e-02, -5.12138525e-01,
#         -1.95281209e-01, -4.83560922e-01, -8.27824005e-03,
#         -3.66489681e-01],
#        [ 3.15643663e-01,  2.11299964e-01,  3.69225200e-01,
#         -1.65892910e-01, -6.60303590e-02, -6.84589785e-03,
#         -1.08208787e-01, -1.50661614e-01, -4.43226628e-01,
# ...

# %%
explained_variances = []
for i in range(len(values)):
    explained_variances.append(values[i] / np.sum(values))
 
print(np.sum(explained_variances), '\n', explained_variances)
# Out:
# 0.9999999999999999
#  [0.40612725625922436, 0.21240398532408303, 0.14558899457015978, 0.07651944897395736, 0.05952148742228069, 0.044032462951424066, 0.017194236281828458, 0.0139526119310183, 0.0008885251251816724, 0.0032068693442114894, 0.0020501633192502116, 0.009555032105132623, 0.008958926392247893]

# %%
projected_1 = X_scaled.dot(vectors.T[0])
projected_2 = X_scaled.dot(vectors.T[1])
res = pd.DataFrame(projected_1, columns=['PC1'])
res['PC2'] = projected_2
res['Y'] = Y
res.head()
# Out:
#         PC1       PC2  Y
# 0  5.287727  0.166563  1
# 1  1.883172  1.126656  2
# 2 -4.226458 -1.439444  1
# 3  0.035344  0.530009  2
# 4 -2.853654  0.386260  3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20, 10))
sns.scatterplot(res['PC1'],[0] * len(res), hue=res['Y'], s=200)
# Out:
# C:\ProgramData\Anaconda2021\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PC1'>

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(res['PC1'], [0] * len(res), hue=res['Y'], s=100)
# Out:
# C:\ProgramData\Anaconda2021\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PC1'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
import pandas as pd
from sklearn.preprocessing import StandardScaler
plt.style.use('ggplot')
# Load the data
#iris = datasets.load_iris()
X = Training_set_I
y = Training_set_I.L
# Z-score the features
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
# The PCA model
pca = PCA(n_components=2) # estimate only 2 PCs
X_new = pca.fit_transform(X) # project the original data into the PCA space
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a3ede97e472b> in <module>
#       8 # Load the data
#       9 #iris = datasets.load_iris()
# ---> 10 X = Training_set_I
#      11 y = Training_set_I.L
#      12 # Z-score the features
#
# NameError: name 'Training_set_I' is not defined

# %%
fig, axes = plt.subplots(1,2)
axes[0].scatter(X[:,0], X[:,1], c=y)
axes[0].set_xlabel('x1')
axes[0].set_ylabel('x2')
axes[0].set_title('Before PCA')
axes[1].scatter(X_new[:,0], X_new[:,1], c=y)
axes[1].set_xlabel('PC1')
axes[1].set_ylabel('PC2')
axes[1].set_title('After PCA')
plt.show()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.40612726 0.21240399]

# %%
np.cov(X_new.T)
# Out:
# array([[5.28493927e+00, 6.57909941e-17],
#        [6.57909941e-17, 2.76401583e+00]])

# %%
pca.explained_variance_
# Out:
# array([5.28493927, 2.76401583])

# %%
print(abs( pca.components_ ))
# Out:
# [[0.26775165 0.31990105 0.37504107 0.31564366 0.34772632 0.31714212
#   0.23766318 0.28929391 0.29839028 0.2306124  0.25150573 0.12491546
#   0.05422478]
#  [0.2547049  0.19316751 0.03656271 0.21129996 0.12793495 0.1511925
#   0.3961777  0.30910588 0.20896354 0.32643931 0.38702405 0.25906512
#   0.43927981]]

# %%
def biplot(score, coeff , y):
    
    xs = score[:,0] # projection on PC1
    ys = score[:,1] # projection on PC2
    n = coeff.shape[0] # number of variables
    plt.figure(figsize=(10,8), dpi=100)
    classes = np.unique(y)
    colors = ['g','r','y']
    markers=['o','^','x']
    for s,l in enumerate(classes):
        plt.scatter(xs[y==l],ys[y==l], c = colors[s], marker=markers[s]) # color based on group
    for i in range(n):
        #plot as arrows the variable scores (each variable has a score for PC1 and one for PC2)
        plt.arrow(0, 0, coeff[i,0], coeff[i,1], color = 'k', alpha = 0.9,linestyle = '-',linewidth = 1.5, overhang=0.2)
        plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'k', ha = 'center', va = 'center',fontsize=10)
    plt.xlabel("PC{}".format(1), size=14)
    plt.ylabel("PC{}".format(2), size=14)
    limx= int(xs.max()) + 1
    limy= int(ys.max()) + 1
    plt.xlim([-limx,limx])
    plt.ylim([-limy,limy])
    plt.grid()
    plt.tick_params(axis='both', which='both', labelsize=14)

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault) # reset ggplot style
# Call the biplot function for only the first 2 PCs
biplot(X_new[:,0:2], np.transpose(pca.components_[0:2, :]), y)
plt.show()

# %%
np.corrcoef(X[:,2], X[:,3])[1,0]
# Out:
# -0.4623854469464068

# %%
np.corrcoef(X[:,1], X[:,2])[1,0]
# Out:
# -0.49123529384568404

# %% [markdown]
# # Task 3: Divide the whole training set into a smaller training set (II) and a validation set.

# %%
Training_set_I.to_csv('Training_set_I.csv', index=False)

# %%
df_new = pd.read_csv("Training_set_I.csv")
df_new.head(1000)
# Out:
#          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 0   -0.0205  1.0804  0.1990  1.1713  0.2044  1.3011 -0.0630  1.8070 -0.1090
# 1    0.2109  0.6045  0.2995  0.9821  0.5221  0.9051  0.3581  0.9091  0.4162
# 2    0.7918 -0.0676  0.9720  0.0902  1.0691  0.1199  1.7815 -0.0586  1.9628
# 3    0.2356  0.2608  0.3491  0.4312  0.5015  0.3656  0.3259  0.4589  0.3623
# 4    0.4731  0.0856  0.7429  0.1325  0.9045  0.0817  0.8110  0.0462  0.8391
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 995  0.0187  0.6936  0.1526  0.8764  0.2685  0.8772 -0.0240  1.7611  0.0566
# 996  0.5597  0.2298  0.8849  0.3551  1.0343  0.3724  1.0940  0.1069  1.1169
# 997  0.5224  0.0097  0.7253  0.1418  0.8516  0.1318  1.6666  0.0734  0.0191
# 998  1.1679 -0.0767  1.1519  0.5657  0.8234  1.0579  1.0611  0.6778  0.6292
# 999  1.0521  0.0665  0.7528  0.9807  0.6024  0.8703  0.7803  0.9460  0.7222
#
#         F10     F11     F12  L
# ...

# %% [markdown]
# a. Take out the last 300 rows from Training_set_I and save them as the validation set.

# %%
validation_set = df_new.iloc[-300:]
validation_set.head(1000)
# Out:
#          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 700  1.1144 -0.0148  0.6321  0.0808  0.5397  0.0414  0.5880  0.1360  0.4192
# 701  0.7495  0.3638  0.3087  0.7132  0.2289  0.5704  0.4013  0.5987  0.4147
# 702  0.3442  0.6581  0.6663  0.8721  0.5898  1.1991  0.6507  0.8913  0.5997
# 703  0.7850  0.3097  1.0392  0.6899  1.0074  0.9179  1.6067  0.1494  2.0236
# 704  0.0514  0.6044  0.1610  0.8481  0.1999  0.9469  0.1133  0.9042  0.1455
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 995  0.0187  0.6936  0.1526  0.8764  0.2685  0.8772 -0.0240  1.7611  0.0566
# 996  0.5597  0.2298  0.8849  0.3551  1.0343  0.3724  1.0940  0.1069  1.1169
# 997  0.5224  0.0097  0.7253  0.1418  0.8516  0.1318  1.6666  0.0734  0.0191
# 998  1.1679 -0.0767  1.1519  0.5657  0.8234  1.0579  1.0611  0.6778  0.6292
# 999  1.0521  0.0665  0.7528  0.9807  0.6024  0.8703  0.7803  0.9460  0.7222
#
#         F10     F11     F12  L
# ...

# %%
validation_set.to_csv('validation_set.csv', index=False)

# %% [markdown]
# b. Save the rest of rows in Training_set_I as the smaller training set (Training set II).

# %%
Training_set_II = df_new.iloc[:700]
Training_set_II.head(1000)
# Out:
#          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 0   -0.0205  1.0804  0.1990  1.1713  0.2044  1.3011 -0.0630  1.8070 -0.1090
# 1    0.2109  0.6045  0.2995  0.9821  0.5221  0.9051  0.3581  0.9091  0.4162
# 2    0.7918 -0.0676  0.9720  0.0902  1.0691  0.1199  1.7815 -0.0586  1.9628
# 3    0.2356  0.2608  0.3491  0.4312  0.5015  0.3656  0.3259  0.4589  0.3623
# 4    0.4731  0.0856  0.7429  0.1325  0.9045  0.0817  0.8110  0.0462  0.8391
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 695  0.5665  0.4000  0.8040  0.4914  0.9725  0.4351  1.7701 -0.0509 -0.0653
# 696  0.1163  0.6281  0.0624  1.1285  0.1577  1.1817  0.0857  1.1037  0.1171
# 697  0.3339  0.6875  0.4558  1.1534  0.6172  1.1920  0.5502  1.0388  0.6202
# 698  1.0390  0.0757  0.7307  1.0098  0.5982  1.3770  0.7363  1.0043  0.6714
# 699  0.6282  0.1157  0.8571  0.3314  1.0491  0.2918  0.8451  0.3437  1.1304
#
#         F10     F11     F12  L
# ...

# %% [markdown]
# # Task 4: Investigate how the number of features in the training dataset affects the model performance on the validation set

# %%
Training_set_II.keys
# Out:
# <bound method NDFrame.keys of          F1      F2      F3      F4      F5      F6      F7      F8      F9  \
# 0   -0.0205  1.0804  0.1990  1.1713  0.2044  1.3011 -0.0630  1.8070 -0.1090
# 1    0.2109  0.6045  0.2995  0.9821  0.5221  0.9051  0.3581  0.9091  0.4162
# 2    0.7918 -0.0676  0.9720  0.0902  1.0691  0.1199  1.7815 -0.0586  1.9628
# 3    0.2356  0.2608  0.3491  0.4312  0.5015  0.3656  0.3259  0.4589  0.3623
# 4    0.4731  0.0856  0.7429  0.1325  0.9045  0.0817  0.8110  0.0462  0.8391
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 695  0.5665  0.4000  0.8040  0.4914  0.9725  0.4351  1.7701 -0.0509 -0.0653
# 696  0.1163  0.6281  0.0624  1.1285  0.1577  1.1817  0.0857  1.1037  0.1171
# 697  0.3339  0.6875  0.4558  1.1534  0.6172  1.1920  0.5502  1.0388  0.6202
# 698  1.0390  0.0757  0.7307  1.0098  0.5982  1.3770  0.7363  1.0043  0.6714
# 699  0.6282  0.1157  0.8571  0.3314  1.0491  0.2918  0.8451  0.3437  1.1304
#
# ...

# %%
print(Training_set_II.columns)
# Out:
# Index(['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11',
#        'F12', 'L'],
#       dtype='object')

# %%
print(Training_set_II.describe())
# Out:
#                F1          F2          F3          F4          F5          F6  \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     0.500625    0.374807    0.561459    0.621596    0.591934    0.595672
# std      0.375830    0.306832    0.327405    0.367976    0.337585    0.358764
# min     -0.094500   -0.194000   -0.076600   -0.125600   -0.078700   -0.102500
# 25%      0.200075    0.102275    0.306275    0.332725    0.324850    0.330825
# 50%      0.419550    0.365650    0.541850    0.589800    0.585750    0.556100
# 75%      0.775525    0.586600    0.775425    0.850100    0.820025    0.806100
# max      1.271900    1.214000    1.839300    1.790700    1.763500    1.880800
#
#                F7          F8          F9         F10         F11         F12  \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     0.804625    0.570118    0.476009    0.844167    0.356398    0.580057
# ...

# %%
print(Training_set_II.L)
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      1
#       ..
# 695    3
# 696    1
# 697    1
# 698    2
# 699    1
# Name: L, Length: 700, dtype: int64

# %%
target = Training_set_II.L
target_names = ['Class 1','Class 2','Class 3']

# %%
print(target)
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      1
#       ..
# 695    3
# 696    1
# 697    1
# 698    2
# 699    1
# Name: L, Length: 700, dtype: int64

# %%
print(target_names)
# Out:
# ['Class 1', 'Class 2', 'Class 3']

# %%
feature_names = ['F1','F2','F3','F4','F5','F6','F7','F8','F9','F10','F11','F12']

# %%
print(feature_names)
# Out:
# ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F11', 'F12']

# %%
Training_set_II.to_csv('Training_set_II.csv', index=False)

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# reading the train and test dataset
train_data = pd.read_csv('Training_set_II.csv')
test_data = pd.read_csv('validation_set.csv')

# %%
# shape of the dataset
print('\nShape of training data :',train_data.shape)
print('\nShape of testing data :',test_data.shape)
# Out:
# Shape of training data : (700, 13)
#
# Shape of testing data : (300, 13)

# %%
# seperate the independent and target variable on training data
train_x = train_data.drop(columns=['L'],axis=1)
train_y = train_data['L']

# %%
# seperate the independent and target variable on training data
test_x = test_data.drop(columns=['L'],axis=1)
test_y = test_data['L']

# %%
model = LinearRegression()

# fit the model with the training data
model.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
# coefficeints of the trained model
print('\nCoefficient of model :', model.coef_)

# intercept of the model
print('\nIntercept of model',model.intercept_)
# Out:
# Coefficient of model : [ 1.46440797  1.32631757 -0.45982128 -1.40492512 -0.89562503 -0.60254762
#   1.78674082  1.76782948 -0.0153142   0.06973913 -1.051616    0.02727288]
#
# Intercept of model 0.6650287305147768

# %%
# predict the target on the test dataset
predict_train = model.predict(train_x)

# Root Mean Squared Error on training dataset
rmse_train = mean_squared_error(train_y,predict_train)**(0.5)
print('\nRMSE on train dataset : ', rmse_train)

# predict the target on the testing dataset
predict_test = model.predict(test_x) 

# Root Mean Squared Error on testing dataset
rmse_test = mean_squared_error(test_y,predict_test)**(0.5)
print('\nRMSE on test dataset : ', rmse_test)
# Out:
# RMSE on train dataset :  0.264813846541781
#
# RMSE on test dataset :  0.3966361226057893

# %%
# importing the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
  
dataset = pd.read_csv('Training_set_II.csv')
dataset.head()
 
# data preprocessing
X = dataset.iloc[:, :1].values  #independent variable array
y = dataset.iloc[:,1].values  #dependent variable vector

print(X)
print(y)
 
# splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=1/3,random_state=0)
 
# fitting the regression model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train) #actually produces the linear eqn for the data
 
# predicting the test set results
y_pred = regressor.predict(X_test) 
y_pred
 
y_test
 
# visualizing the results
#plot for the TRAIN
  
plt.scatter(X_train, y_train, color='blue') # plotting the observation line
plt.plot(X_train, regressor.predict(X_train), color='red') # plotting the regression line
plt.title("Functions vs Classes (Training set)") # stating the title of the graph
  
plt.xlabel("Functions") # adding the name of x-axis
plt.ylabel("Classes") # adding the name of y-axis
plt.show() # specifies end of graph
 
#plot for the TEST
  
plt.scatter(X_test, y_test, color='red') 
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("Functions vs Classes (Testing set)")
  
plt.xlabel("Functions") 
plt.ylabel("Classes") 
plt.show()
# Out:
# [[-2.0500e-02]
#  [ 2.1090e-01]
#  [ 7.9180e-01]
#  [ 2.3560e-01]
#  [ 4.7310e-01]
#  [ 2.5090e-01]
#  [ 4.4960e-01]
#  [ 1.1220e-01]
#  [ 3.1160e-01]
#  [ 1.0280e+00]
#  [ 2.4720e-01]
#  [ 4.1670e-01]
#  [ 5.0300e-02]
#  [ 3.5120e-01]
#  [ 8.8840e-01]
#  [ 3.5370e-01]
#  [ 1.1152e+00]
#  [ 3.0250e-01]
#  [ 6.9000e-02]
#  [ 4.8970e-01]
#  [ 1.1604e+00]
#  [ 1.0791e+00]
#  [ 5.2700e-02]
#  [ 6.0510e-01]
#  [ 1.0964e+00]
#  [ 1.3090e-01]
#  [ 6.4580e-01]
#  [ 1.0740e+00]
#  [ 3.8950e-01]
#  [ 2.3790e-01]
#  [ 2.0770e-01]
#  [ 5.8830e-01]
#  [ 1.0480e+00]
#  [ 6.4200e-01]
#  [ 8.3800e-02]
#  [ 4.5160e-01]
#  [ 5.5850e-01]
#  [ 4.6490e-01]
#  [ 1.2555e+00]
#  [ 1.1406e+00]
#  [ 7.7410e-01]
#  [ 9.3900e-02]
#  [ 2.7550e-01]
#  [ 3.9280e-01]
#  [ 2.4570e-01]
#  [ 5.4250e-01]
#  [ 2.7040e-01]
#  [ 6.9900e-01]
#  [ 4.0390e-01]
#  [ 5.3400e-02]
#  [ 3.0170e-01]
#  [-4.5800e-02]
#  [ 8.3530e-01]
#  [ 8.1100e-02]
#  [ 5.4600e-02]
#  [ 3.5680e-01]
#  [ 3.7670e-01]
#  [ 1.1308e+00]
# ...

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
dataset = pd.read_csv('Training_set_II.csv')

# %%
dataset.shape
# Out:
# (700, 13)

# %%
dataset.describe()
# Out:
#                F1          F2          F3          F4          F5          F6  \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     0.500625    0.374807    0.561459    0.621596    0.591934    0.595672
# std      0.375830    0.306832    0.327405    0.367976    0.337585    0.358764
# min     -0.094500   -0.194000   -0.076600   -0.125600   -0.078700   -0.102500
# 25%      0.200075    0.102275    0.306275    0.332725    0.324850    0.330825
# 50%      0.419550    0.365650    0.541850    0.589800    0.585750    0.556100
# 75%      0.775525    0.586600    0.775425    0.850100    0.820025    0.806100
# max      1.271900    1.214000    1.839300    1.790700    1.763500    1.880800
#
#                F7          F8          F9         F10         F11         F12  \
# count  700.000000  700.000000  700.000000  700.000000  700.000000  700.000000
# mean     0.804625    0.570118    0.476009    0.844167    0.356398    0.580057
# ...

# %%
dataset.plot(x='F1',y='L', style='o')  
plt.title('F vs L')  
plt.xlabel('F1')  
plt.ylabel('L')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset['L'])
# Out:
# C:\ProgramData\Anaconda2021\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='L', ylabel='Density'>

# %%
X = dataset['F1'].values.reshape(-1,1)
y = dataset['L'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression()

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [2.10350911]
# [[-0.15733407]]

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#      Actual  Predicted
# 0         1   2.042290
# 1         3   2.009895
# 2         1   1.981717
# 3         2   1.940023
# 4         3   1.963734
# ..      ...        ...
# 135       2   1.935822
# 136       3   2.073915
# 137       1   2.047829
# 138       2   1.936499
# 139       2   1.930332
#
# [140 rows x 2 columns]

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10),color=('green','yellow'))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='blue')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='orange', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.7761187388028213
# Mean Squared Error: 0.7670402604843678
# Root Mean Squared Error: 0.8758083468912407

# %%
dataset_test = pd.read_csv('Training_set_I.csv')

# %%
dataset_test.shape
# Out:
# (1000, 13)

# %%
dataset_test.describe()
# Out:
#                 F1           F2           F3           F4           F5  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.496805     0.372134     0.557155     0.620912     0.590370
# std       0.374432     0.304255     0.321035     0.360595     0.335750
# min      -0.094500    -0.194000    -0.076600    -0.125600    -0.078700
# 25%       0.205725     0.102150     0.311275     0.341925     0.331400
# 50%       0.416650     0.365650     0.548250     0.594900     0.577900
# 75%       0.755800     0.590175     0.756025     0.841525     0.816225
# max       1.271900     1.214000     1.839300     1.790700     1.891400
#
#                 F6           F7           F8           F9          F10  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.593608     0.800390     0.569042     0.464324     0.853483
# std       0.349200     0.623070     0.540683     0.518869     0.718046
# ...

# %%
dataset_test.plot(x='F1', y='L', style='o')  
plt.title('F vs L')  
plt.xlabel('F')  
plt.ylabel('L')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset_test['L'])
# Out:
# C:\ProgramData\Anaconda2021\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='L', ylabel='Density'>

# %%
X = dataset_test['F1'].values.reshape(-1,1)
y = dataset_test['L'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression()

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [2.08970573]
# [[-0.17116539]]

# %%
y_pred = regressor.predict(X_test)

# %%
df_test = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df_test
# Out:
#      Actual  Predicted
# 0         1   2.028429
# 1         3   2.058211
# 2         3   2.088371
# 3         3   1.942093
# 4         3   1.993682
# ..      ...        ...
# 195       3   2.018244
# 196       2   2.030688
# 197       1   2.090082
# 198       2   1.911968
# 199       1   2.068430
#
# [200 rows x 2 columns]

# %%
df_test1 = df_test.head(25)
df_test1.plot(kind='bar',figsize=(16,10),color=('red','yellow'))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='pink')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.7117378657485176
# Mean Squared Error: 0.6868625642466586
# Root Mean Squared Error: 0.8287717202261782

# %% [markdown]
# # Task 5: Findings and Conclusions
